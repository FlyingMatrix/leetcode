# %%
# 21 - Merge Two Sorted Lists
"""
    You are given the heads of two sorted linked lists list1 and list2.

    Merge the two lists into one sorted list. The list should be made by splicing together the nodes of the first two lists.

    Return the head of the merged linked list.

    Example 1:
        Input: list1 = [1,2,4], list2 = [1,3,4]
        Output: [1,1,2,3,4,4]

    Example 2:
        Input: list1 = [], list2 = []
        Output: []

    Example 3:
        Input: list1 = [], list2 = [0]
        Output: [0]
"""

# %%
# My accepted solution:
#
# Definition for singly-linked list.
# class ListNode(object):
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution(object):
    def mergeTwoLists(self, list1, list2):
        """
        :type list1: Optional[ListNode]
        :type list2: Optional[ListNode]
        :rtype: Optional[ListNode]
        """
        if list1 == None:
            return list2
        if list2 == None:
            return list1
        new_list = ListNode(0)
        output = new_list
        current1 = list1
        current2 = list2
        while current1 and current2:
            if current1.val <= current2.val:
                output.next = current1
                current1 = current1.next
            else:
                output.next = current2
                current2 = current2.next
            output = output.next
        if current1:
            output.next = current1
        else:
            output.next = current2
        return new_list.next

# %%
# Time complexity: O(m+n), while m = number of nodes in list1, n = number of nodes in list2
# Space complexity: O(1) (auxiliary), the output list itself uses O(n+m) space, 
#                   but that is not counted against space complexity since it is required output
